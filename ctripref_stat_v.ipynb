# %% [markdown]
# # Visualize Ctripref Coverage Stats
#
# Run stats and dump csv

# %%
import subprocess

subprocess.call(['python', 'ctripref_stats_gai.py', 
                 '--days', '-10'])

print('Task compelte!')
# Out:
# Task compelte!

# %% [markdown]
# Take lastest csv and draw

# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt
from matplotlib.ticker import FuncFormatter

import glob, os

newest = max(glob.iglob('output_hotel_ref_stats_*.csv'), key=os.path.getctime)
print(newest)

headers = ['date', '#_of_bookings', '#_of_hotel_ref', 'comment', 'coverage']
df = pd.read_csv(newest)
print(df)
ax = df.plot(x='date', y='coverage', style='o-')
plt.gcf().autofmt_xdate()
# ax.set_yticklabels(['{:3.2f}%'.format(x*100) for x in vals])
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
# Out:
# output_hotel_ref_stats_171226_1203.csv
#          date  #_of_bookings  #_of_hotel_ref  comment  coverage
# 0  2017-12-16            650             444      NaN     0.683
# 1  2017-12-17            494             361      NaN     0.731
# 2  2017-12-18            474             318      NaN     0.671
# 3  2017-12-19            493             347      NaN     0.704
# 4  2017-12-20            550             428      NaN     0.778
# 5  2017-12-21            585             442      NaN     0.756
# 6  2017-12-22            746             577      NaN     0.773
# 7  2017-12-23            858             676      NaN     0.788
# 8  2017-12-24            758             551      NaN     0.727
# 9  2017-12-25            594             455      NaN     0.766
# <img src="data:image/png;base64,..." width="640">
