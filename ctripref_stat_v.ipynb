# %% [markdown]
# # Visualize Ctripref Coverage Stats
#
# Run stats and dump csv

# %%
import subprocess

subprocess.call(['python', 'ctripref_stats_gai.py', 
                 '--days', '-10'])

print('Task compelte!')
# Out:
# Task compelte!

# %% [markdown]
# Take lastest csv and draw

# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt
from matplotlib.ticker import FuncFormatter

import glob, os

newest = max(glob.iglob('output_hotel_ref_stats_*.csv'), key=os.path.getctime)
print(newest)

headers = ['date', '#_of_bookings', '#_of_hotel_ref', 'comment', 'coverage']
df = pd.read_csv(newest)
print(df)
ax = df.plot(x='date', y='coverage', style='o-')
plt.gcf().autofmt_xdate()
# ax.set_yticklabels(['{:3.2f}%'.format(x*100) for x in vals])
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
# Out:
# output_hotel_ref_stats_180109_1013.csv
#          date  #_of_bookings  #_of_hotel_ref  comment  coverage
# 0  2017-12-30            875             691      NaN     0.790
# 1  2017-12-31            815             625      NaN     0.767
# 2  2018-01-01            709             529      NaN     0.746
# 3  2018-01-02            497             352      NaN     0.708
# 4  2018-01-03            538             377      NaN     0.701
# 5  2018-01-04            458             362      NaN     0.790
# 6  2018-01-05            518             409      NaN     0.790
# 7  2018-01-06            466             349      NaN     0.749
# 8  2018-01-07            409             288      NaN     0.704
# 9  2018-01-08            402             290      NaN     0.721
# <img src="data:image/png;base64,..." width="640">
