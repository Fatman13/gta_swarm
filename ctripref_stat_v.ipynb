# %% [markdown]
# # Visualize Ctripref Coverage Stats
#
# Run stats and dump csv

# %%
import subprocess

subprocess.call(['python', 'ctripref_stats_gai.py', 
                 '--days', '-10'])

print('Task compelte!')
# Out:
# Task compelte!

# %% [markdown]
# Take lastest csv and draw

# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib

from matplotlib import pyplot as plt
from matplotlib.ticker import FuncFormatter

import glob, os

newest = max(glob.iglob('output_hotel_ref_stats_*.csv'), key=os.path.getctime)
print(newest)

headers = ['date', '#_of_bookings', '#_of_hotel_ref', 'comment', 'coverage']
df = pd.read_csv(newest)
print(df)
ax = df.plot(x='date', y='coverage', style='o-')
plt.gcf().autofmt_xdate()
# ax.set_yticklabels(['{:3.2f}%'.format(x*100) for x in vals])
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
# Out:
# output_hotel_ref_stats_171114_1016.csv
#          date  #_of_bookings  #_of_hotel_ref  comment  coverage
# 0  2017-11-04            531             374      NaN     0.704
# 1  2017-11-05            441             273      NaN     0.619
# 2  2017-11-06            423             290      NaN     0.686
# 3  2017-11-07            377             286      NaN     0.759
# 4  2017-11-08            393             299      NaN     0.761
# 5  2017-11-09            433             322      NaN     0.744
# 6  2017-11-10            606             453      NaN     0.748
# 7  2017-11-11            518             344      NaN     0.664
# 8  2017-11-12            351             267      NaN     0.761
# 9  2017-11-13            518             367      NaN     0.708
# <img src="data:image/png;base64,..." width="640">
